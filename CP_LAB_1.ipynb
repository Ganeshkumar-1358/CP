# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganeshkumar-1358/CP/blob/main/CP_LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def max_meetings(meetings):
    meetings.sort(key=lambda x: x[1])
    count = 0
    last_end = -1
    for s, e in meetings:
        if s >= last_end:
            count += 1
            last_end = e
    return count
T = int(input())
for _ in range(T):
    N = int(input())
    meetings = [tuple(map(int, input().split())) for _ in range(N)]
    print(max_meetings(meetings))
